# %% [markdown]
# ## Data Set from Kaggle
#
# Recognized the wealth of crucial information within biomedical texts pivotal for advancements in the medical domain.
#
# Advocated for the automation of event extraction from biomedical texts to accelerate progress and innovation within the medical field, emphasizing the substantial benefits of this approach.
#
# https://www.kaggle.com/datasets/nishanthsalian/genia-biomedical-event-dataset?select=GE11-LICENSE

# %%
import pandas as pd

# %%
train = pd.read_csv('train_data.csv')

# %%
test = pd.read_csv('test_data.csv')

# %%
train.shape
# Out:
# (8666, 4)

# %%
test.shape
# Out:
# (3360, 4)

# %%
train.head()
# Out:
#                                             Sentence  \
# 0   Down-regulation of interferon regulatory fact...
# 1   Although the bcr - abl translocation has been...
# 2   Promoter methylation of CpG target sites or d...
# 3   Therefore , we investigated whether IRF-4 pro...
# 4   Whereas promoter mutations or structural rear...
#
#                                    TriggerWord TriggerWordLoc  \
# 0                  Down-regulation;expression;           1;8;
# 1                                deregulation;            30;
# 2                                          NaN            NaN
# 3                       regulation;expression;         16;19;
# 4  altered;expression;influence;transcription;   14;16;30;32;
#
#                                            EventType
# 0               Negative_regulation;Gene_expression;
# 1                                        Regulation;
# 2                                                NaN
# 3                        Regulation;Gene_expression;
# 4  Regulation;Gene_expression;Regulation;Transcri...

# %%
test.head()
# Out:
#                                             Sentence  TriggerWord  \
# 0   Resistance to IL-10 inhibition of interferon ...          NaN
# 1   IL-10 has been shown to block the antigen-spe...          NaN
# 2   We found that peripheral blood CD4 + T cells ...          NaN
# 3   The phosphorylation of signal transducer and ...          NaN
# 4   Sera from RA patients induced signal transduc...          NaN
#
#    TriggerWordLoc  EventType
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN

# %%
## Concatination of 2 data frames vertically
data = pd.concat([train,test],axis=0)

# %%
data.shape
# Out:
# (12026, 4)

# %%
data.isnull().mean()
# Out:
# Sentence          0.000000
# TriggerWord       0.691585
# TriggerWordLoc    0.691585
# EventType         0.691585
# dtype: float64

# %%
data.TriggerWord.unique()
# Out:
# array(['Down-regulation;expression;', 'deregulation;', nan, ...,
#        'expressed;cross-linking;augmented;expression;transcription;up-regulated;activated;transcription;cross-linking;',
#        'up-regulate;expression;', 'expression;levels;'], dtype=object)

# %%
data['TriggerWord'].value_counts().iloc[:50]
# Out:
# expression;                     182
# expressed;                       90
# binding;                         54
# binds;                           36
# bind;                            36
# induction;                       32
# overexpression;                  29
# expression;expression;           28
# activation;                      28
# induced;                         26
# express;                         24
# activated;                       24
# bound;                           23
# regulation;                      22
# expressing;                      20
# cross-linking;                   18
# increase;                        18
# transcription;                   18
# increased;                       17
# regulated;                       17
# production;                      17
# Overexpression;                  15
# induced;expression;              15
# detected;                        14
# Expression;                      14
# interact;                        13
# produced;                        13
# interaction;                     13
# expression;regulated;            12
# regulation;expression;           12
# increased;expression;            12
# interacts;                       11
# Regulation;expression;           11
# levels;                          11
# ligation;                        11
# inhibited;                       10
# effect;                          10
# producing;                       10
# localization;                    10
# expression;induced;               9
# deficient;                        9
# target;                           8
# decreased;                        8
# phosphorylation;degradation;      8
# present;                          8
# induce;expression;                8
# regulate;expression;              8
# found;                            7
# regulate;                         7
# secretion;                        7
# Name: TriggerWord, dtype: int64

# %%
data['EventType'].value_counts().iloc[:50]
# Out:
# Gene_expression;                                                428
# Positive_regulation;                                            378
# Binding;                                                        310
# Positive_regulation;Gene_expression;                            178
# Negative_regulation;                                            152
# Regulation;                                                     147
# Regulation;Gene_expression;                                     103
# Positive_regulation;Positive_regulation;                         96
# Transcription;                                                   91
# Gene_expression;Positive_regulation;                             81
# Gene_expression;Gene_expression;                                 64
# Negative_regulation;Gene_expression;                             62
# Negative_regulation;Positive_regulation;                         52
# Localization;                                                    49
# Positive_regulation;Transcription;                               48
# Gene_expression;Negative_regulation;                             37
# Gene_expression;Regulation;                                      29
# Regulation;Transcription;                                        28
# Binding;Binding;                                                 28
# Positive_regulation;Negative_regulation;                         27
# Positive_regulation;Localization;                                26
# Positive_regulation;Positive_regulation;Gene_expression;         25
# Positive_regulation;Positive_regulation;Positive_regulation;     22
# Negative_regulation;Positive_regulation;Gene_expression;         22
# Positive_regulation;Regulation;                                  21
# Positive_regulation;Gene_expression;Positive_regulation;         21
# Positive_regulation;Binding;                                     21
# Transcription;Positive_regulation;                               20
# Regulation;Positive_regulation;                                  20
# Regulation;Regulation;                                           18
# Binding;Positive_regulation;                                     18
# Negative_regulation;Transcription;                               17
# Negative_regulation;Binding;                                     16
# Gene_expression;Binding;                                         13
# Gene_expression;Positive_regulation;Positive_regulation;         12
# Phosphorylation;                                                 12
# Gene_expression;Negative_regulation;Gene_expression;             12
# Positive_regulation;Gene_expression;Gene_expression;             12
# Gene_expression;Positive_regulation;Gene_expression;             12
# Localization;Positive_regulation;                                12
# Regulation;Binding;                                              12
# Positive_regulation;Positive_regulation;Transcription;           12
# Protein_catabolism;                                              11
# Positive_regulation;Protein_catabolism;                          11
# Positive_regulation;Phosphorylation;                             11
# Regulation;Positive_regulation;Gene_expression;                  11
# Negative_regulation;Negative_regulation;                         11
# Positive_regulation;Negative_regulation;Positive_regulation;     10
# Negative_regulation;Localization;                                10
# Positive_regulation;Gene_expression;Negative_regulation;         10
# Name: EventType, dtype: int64

# %%
data['EventType']=data['EventType'].str.split(';').str[0]

# %%
data['EventType'].fillna(data['EventType'].mode()[0],inplace=True)

# %%
data['EventType'].value_counts()
# Out:
# Positive_regulation    9488
# Gene_expression         785
# Negative_regulation     521
# Regulation              445
# Binding                 439
# Transcription           187
# Localization             89
# Phosphorylation          52
# Protein_catabolism       20
# Name: EventType, dtype: int64

# %%
data.isnull().sum()
# Out:
# Sentence             0
# TriggerWord       8317
# TriggerWordLoc    8317
# EventType            0
# dtype: int64

# %%
y = data['EventType']

# %%
data.reset_index(inplace=True)

# %%
import re
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
WordNet = WordNetLemmatizer()
corpus = []
for i in range(0,len(data)):
    review = re.sub('[^a-zA-Z]',' ',data['Sentence'][i])
    review = review.lower()
    review = review.split()
    review = [WordNet.lemmatize(word) for word in review if word not in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['regulation interferon regulatory factor gene expression leukemic cell due hypermethylation cpg motif promoter region',
#  'although bcr abl translocation shown causative genetic aberration chronic myeloid leukemia cml mounting evidence deregulation gene transcription factor interferon regulatory factor irf also implicated pathogenesis cml',
#  'promoter methylation cpg target site direct deletion insertion gene mechanism reversible permanent silencing gene expression respectively',
#  'therefore investigated whether irf promoter methylation mutation may involved regulation irf expression leukemia cell',
#  'whereas promoter mutation structural rearrangement could excluded cause altered irf expression hematopoietic cell irf promoter methylation status found significantly influence irf transcription',
#  'first treatment irf negative lymphoid myeloid monocytic cell line methylation inhibitor aza deoxycytidine resulted time concentration dependent increase irf mrna protein level',
#  'second using restriction pcr assay bisulfite sequencing identified specifically methylated cpg site irf negative irf positive cell',
#  'third clearly determined promoter methylation mechanism irf regulation via reporter gene assay detect association methylational status mrna expression dna methyltransferases methyl cpg binding protein',
#  'together data suggest cpg site specific irf promoter methylation putative mechanism regulated irf expression leukemia',
#  'chronic myeloid leukemia cml clonal myeloproliferative disorder typical three phased course chronic accelerated blastic phase reflecting loss differentiation malignant progress inevitably lead death blastic phase',
#  'hallmark genetic aberration cml reciprocal chromosomal translocation leading expression bcr abl fusion gene aberrant activated tyrosine kinase',
#  'treatment interferon alpha ifn alpha prolongs survival cml patient associated complete cytogenetic response cml patient',
#  'recently described impaired expression interferon regulatory factor irf cml correlating poor response ifn alpha treatment',
#  'cause silencing irf level remained unclear',
#  'interferon regulatory factor irfs family transcriptional regulator defined characteristic homology dna binding domain',
#  'play important role regulation various gene ifns interleukin mhc class ii apoptosis differentiation maturation',
#  'irf icsat pip mum lsirf one member restricted expression pattern predominately b activated lymphocyte irf positive',
#  'contrast irfs expression irf induced ifns antigen stimulation crosslinking b cell receptor phorbol myristate acetate',
#  'consistent restriction expression immunocompetent cell mouse deletion irf failed develop mature functionally active b lymphocyte impaired expression irf cml predominately found cell',
#  'data suggest crucial role irf function immune cell',
#  'methylation dinucleotide cytosine guanosine motif cpg especially cpg island located promoter region one mechanism gene regulation mammal common event gene silencing human neoplasia',
#  'opposed normal cell hypermethylation cpg island frequently observed phenomenon every cancer type',
#  'de novo dna methylation gene cell cycle dna repair apoptosis tumor suppressor gene therefore thought involved tumorigenesis',
#  'example aberrated gene mgmt dapk p arf p ink b p ink brca cdh apaf',
#  'cml methylation known regulate expression c abl bcr gene others extent methylation c abl promoter shown associated advanced disease',
#  'hypermethylation due overexpression dna methyltransferases dnmts remains one possible explanation de novo methylation tumorigenesis',
#  'recently dnmts shown regulated hematopoietic malignancy',
#  'methyl cpg binding protein mbps thought inhibit binding transcriptional factor promoter therefore discussed one mechanism transcription inhibition hypermethylation',
#  'work studied mechanism irf gene expression silencing leukemic cell',
#  'analyzed irf promoter region genetic aberration methylational status irf positive negative hematopoietic cell',
#  'cell line',
#  'k jurkat u obtained atcc american type culture collection rockville usa em lama cml bv sd rpmi dsmz deutsche sammlung von mikroorganismen und zellkulturen gmbh braunschweig germany',
#  'cell line except bv sd rpmi irf negative',
#  'cell culture stimulation',
#  'cell line maintained co rpmi medium glutamine gibco brl eggenstein germany supplemented fetal calf serum gibco brl penicillin streptomycin biochrom berlin germany',
#  'indicated cell treated aza deoxycytidine azadc azacytidine azac sigma taufkirchen germany different time period',
#  'owing chemical instability fresh substance added every h',
#  'sequencing irf promoter',
#  'analysis irf promoter region permanent aberration insertion deletion mutation pcr amplified two fragment genomic dna extracted depicted cell line commercial kit qiagen hilde germany recommended',
#  'primer forward ttgagatggagtcttgctctgt reverse ccaggacctcaggaggccagtca forward agcggtgaaactgagagtgcgaggt reverse gccacatcgctgcagtttag',
#  'product cloned topo ta cloning kit invitrogen groningen netherlands',
#  'bacterial amplification cloned pcr fragment standard procedure least three clone sample sequenced automated sequencer abi prism applied bio system foster city usa recommended manufacturer',
#  'expression analysis',
#  'analyze irf transcriptional level rna extracted cell using commercial rnazol kit paesel frankfurt germany',
#  'aliquot mug total rna used cdna synthesis described previously',
#  'rna expression analysis irf reference gene beta actin carried semi quantitative pcr described previously',
#  'pcr product verified automated sequencing',
#  'pcr primer condition expression analysis dnmt mbp dnmt dnmt dnmt b mecp mbd mbd mbd published elsewhere',
#  'analysis irf protein expression standard immunoblotting assay performed described previously',
#  'briefly protein lysates generated incubating x cell microl ripa buffer np sodiumdesoxycholate sd microg ml phenylmethylsulfonyl fluoride microl ml protease inhibitory mix micromol ml sodiumorthovanadate phosphate buffered saline min ice',
#  'centrifugation protein concentration supernatant determined bca method pierce rockford il recommended',
#  'protein lysates microg electrophoresed polyacrylamide gel transferred pvdf membrane immobilon p microm millipore eschborn germany',
#  'membrane blocked blocking reagent boehringer mannheim germany tbst buffer g l tris hcl g l trisoh g l nacl g l kcl microl l tween h subsequently incubated primary antibody indicated horseradish peroxidase conjugated secondary antibody anti mouse anti goat igg dako hamburg germany respectively',
#  'membrane developed ecl detection kit amersham pharmacia biotech freiburg germany',
#  'primary antibody goat anti irf icsat santa cruz biotechnology santa cruz ca mouse anti beta actin ac sigma',
#  'methylation specific restriction pcr assay',
#  'dna extracted commercial kit qiagen recommended',
#  'since restriction ability several endonuclease inhibited methylation target sequence used methylation sensitive enzyme hpaii haeii isochizomer bsp ii bsh mbi fermentas st leon rot germany',
#  'control methylation resistant enzyme mspi enzyme recognition site target promoter ecori used',
#  'dna microg digested u respective enzyme h ensure complete cleavage additional u h',
#  'thereafter ng digested dna used pcr amplification two fragment f f spanning part irf promoter genbank u see figure',
#  'sequence primer f forward ttgagatggagtcttgctctgt f reverse atcacttccagacttcagttcacct bp f forward aaggtgaactgaagtctggaagtga f reverse ccaggacctcaggaggccagtca bp',
#  'pcr condition described elsewhere',
#  'pcr performed annealing temperature degreesc cycle',
#  'dna methylated specific site sensitive enzyme able digest dna amplification took place case methylation dna digested product generated',
#  'pcr product electrophoresed agarose gel stained ethidium bromide photographed',
#  'pcr product verified automated sequencing',
#  'bisulfite treatment',
#  'dna extracted described',
#  'bisulfite treatment dna leading conversion unmethylated cytosine uracil residue change methylated cytosine residue performed described follows',
#  'briefly microg dna microg poly da dt poly da dt copolymer amersham pharmacia biotech denaturated min degreesc naoh volume microl',
#  'fresh solution microl mm hydrochinon sigma microl sodium bisulfite ph sigma added solution gently mixed overlayed mineral oil incubated dark h degreesc',
#  'aqueous phase recovered using wizard dna clean system promega mannheim germany',
#  'purified dna subsequently mixed naoh final concentration incubated min degreesc ensure complete desulfonisation',
#  'dna ethanol precipitated presence vol sodium acetate washed ethanol resuspended microl h',
#  'subsequent pcr amplification microl bisulfite treated dna used cloning two fragment irf promoter b b ii pcr vector topo ta cloning kit invitrogen see figure',
#  'primer used pcr amplification b b ii fragment contain putative altered sequence sense strand due bisulfite treatment converted cytosine residue written bold letter b forward tatttggatttttagggagtttttttt b reverse acccaactcccttaaactattaaact bp b ii forward agtttaatagtttaagggagttgggt b ii reverse ctcaccctaaactcaaaactaaaaac bp',
#  'bacterial amplification cloned pcr fragment standard procedure eight clone sample sequenced automated sequencer abi prism applied biosystems',
#  'vitro methylation reporter gene assay',
#  'irf promoter reporter gene construct generously provided j hiscott',
#  'construct methylated vitro cpg methylase ss recommended manufacturer ne biolabs complete methylation checked via restriction analysis figure',
#  'reporter gene assay using dual luciferase assay promega performed similar previous report',
#  'briefly nm reporter construct transfection control construct expressing renilla luciferase gene transiently co expressed via electroporation',
#  'control construct served internal reference transfection efficiency',
#  'forty eight hour transfection luciferase activity measured lb p microlumat eg g berthold bad wildbad germany',
#  'irf promoter activation quantified ratio measured firefly light unit flu relative renilla rlu',
#  'experiment carried least three time',
#  'absence irf expression leukemia cell due promoter alteration',
#  'previously demonstrated lack irf expression leukemia patient specifically cml cell',
#  'demonstrate absence irf expression various hematopoietic cell line jurkat cell leukemia cml bcr abl positive cell line k bcr abl positve erythroleukemia u monocytic leukemia em lama bcr abl positve myeloid leukemia sd bcr abl positive acute lymphoblastic leukemia pre b rpmi multiple myeloma bv bcr abl positive b cell line figure',
#  'sequencing irf promoter could excluded absence irf expression cell line due genetic aberration',
#  'however bp change nucleotide c c could detected irf positive bv irf negative lama em k figure b',
#  'position c substitution found em k cml whereas jurkat bv sd exhibited mixed c sequence u lama rpmi substitution figure b',
#  'consequently alteration unlikely affect irf expression',
#  'increase irf expression hematopoietic cell demethylating treatment',
#  'next analyzed whether promoter methylation could responsible regulation irf expression',
#  'region including exon irf promoter exhibited large number cpg rich sequence figure',
#  'several chemical substance aza deoxycytidine azadc azacytidine azac inhibit de novo maintenance methylation thus used discern promoter methylation',
#  'used azadc generate unmethylated dna',
#  'h azadc treatment resulted concentration dependent activation irf transcription jurkat cml cell well u k em cell line figure',
#  'irf transcription induced time dependent manner observed early h treatment azadc increased time h figure b',
#  'time strength appearance irf transcript varied among cell line e cml responded strongest azadc treatment data shown',
#  'line azadc treatment cml lama cell also translated induction irf protein expression figure c',
#  'accordingly treatment irf positive cell line bv sd rpmi azadc effect irf expression figure',
#  'difference effect azac versus azadc increased irf mrna level cml cell well data shown',
#  'implied promoter methylation may control irf expression alternative explanation may activation positive transcriptional regulator irf azadc azac',
#  'methylation sensitive enzyme cut specific site irf promoter hematopoietic cell',
#  'investigate promoter methylation regulatory mechanism irf gene expression restriction pcr assay performed methylated dna would cut enabling subsequent pcr amplification vice versa',
#  'genomic dna leukemic cell jurkat cml u k em bv digested methylation sensitive enzyme hpaii bsh haeii isochizomer bsp ii',
#  'ecori recognition site within irf promoter methylation resistant enzyme mspi served control',
#  'two separate amplification reaction performed generating two fragment f f figure',
#  'digestion hpaii bsp ii sufficient pcr amplification f f detected dna irf negative jurkat cml u k em cell suggesting promoter methylation restriction protection respective recognition site figure b c',
#  'notably irf positive sd cell digestion methylation sensitive enzyme completely inhibited amplification f f',
#  'irf positive bv cell hpaii bsh digestion significantly reduced amplifiable dna message f figure c whereas amplification f affected figure b',
#  'implied irf transcription sd bv cell associated le promoter methylation bv especially hpaii site compared tested irf negative cell',
#  'specific cpg site irf promoter methylated hematopoietic cell',
#  'order exactly map methylation site within irf promoter treated dna jurkat cml u k em cell well sd rpmi bv control cell bisulfite chemically convert unmethylated cytosine uracil whereas effect methylated cytosine e cpg',
#  'technique especially useful detection unknown methylation pattern',
#  'pcr amplification cloning sequencing bisulfite treated dna showed specific methylation pattern analyzed cpg site cell line figure table',
#  'general methylational status ranged one cell line nearly non methylated irf promoter sd irf positive completely methylated irf promoter cml irf negative',
#  'interestingly percentage cpg methylation irf promoter irf positive cell low mean compared irf negative cell mean figure table',
#  'region r hypermethylated cpg site mean number methylated clone methylated cpgs found cell except sd rpmi region r hypomethylated cpg site mean number methylated clone methylated cpgs found cell except cml u figure table',
#  'intriguingly stretch cpg site r detected region highly methylated irf negative mean number methylated clone methylated cpgs totally non methylated irf positive cell figure b',
#  'furthermore three cpg site end two cpg motif end showed direct correlation high methylation status absence irf expression',
#  'addition two cpg site located nfkappab sp element le methylated irf positive irf negative cell mean number methylated clone versus',
#  'result indicate involvement cpg methylation regulation irf expression leukemic cell',
#  'vitro methylation irf promoter reporter construct decrease activity',
#  'provide evidence direct effect methylational status irf promoter activity performed reporter gene assay irf promoter construct vitro methylation',
#  'complete methylation construct checked via restriction assay methylation sensitive endonuclease figure',
#  'intriguingly methylation irf promoter significantly decreased promoter activity irf positive sd cell figure b',
#  'silencing effect cpg methylation restricted irf positive cell since vitro methylation led abrogation promoter activity irf negative jurkat cell figure c',
#  'contrast control methylation reporter construct different promoter fasl well empty vector effect reporter activity data shown',
#  'data proved direct association methylation activity irf promoter',
#  'mrna expression dna methyltransferases methyl cpg binding protein may associated irf promoter methylation',
#  'since abundance dnmt mbp contribute promoter regulation via methylation studied mrna expression investigate possible mechanism observed methylation difference irf promoter',
#  'end detect significant difference dnmt dnmt dnmt dnmt b mbp mbd mbd mbd mecp mrna expression irf positive negative cell figure',
#  'fact analyzed cell moderate high mrna level tested dnmt mbps difference expression correlated irf status',
#  'result indicate distinct cause methylation difference irf positive negative cell rather change dnmt mbp mrna transcription',
#  'many genetic lesion known influence gene expression tumor suppressor gene',
#  'whereas mutation deletion insertion permanent effect reversible mechanism gene methylation expression activation transcription factor respectively',
#  'studied putative cause absent irf expression leukemia cell first focused genetic aberration promoter',
#  'observed genetic alteration irf promoter account lack irf expression detected base pair change position c substitution position c substitution position c substitution unlikely responsible absent irf expression since first two mutation found irf positive negative cell whereas latter change detected consistently irf negative positive cell may thus polymorphism',
#  'three substitution change known putative transcription factor binding site also affect restriction site primer binding site used assay',
#  'however permanent genetic variation irf coding sequence deletion mutation resulting stop codon excluded sequence analysis',
#  'since irf expression cell line cml induced demethylation successful ifn alpha therapy respectively existence genetic aberration seems unlikely',
#  'investigated whether previously described regulation irf expression human myeloid leukemia due differential hypermethylation promoter since presented expression due azadc treatment might also result activation positive transcriptional regulator irf',
#  'methylation cpg site common mechanism silencing gene leukemia also shown another irf irf pu interacting partner irf',
#  'elucidate relevance mechanism regulation irf expression various leukemic cell treated demethylating agent promoter sequenced bisulfite treatment',
#  'found irf expression could indeed connected methylation status distinct cpg motif irf promoter',
#  'figure cpg site shown bottom line whose hypermethylation may account absence irf expression respective cell',
#  'one adjacent identified regulatory element nfkappab site indicating possible involvement site',
#  'two cpg site methylation status irf positive lower irf negative cell',
#  'cpg site located nfkappab sp element thus may also play role regulation irf expression',
#  'shown nfkappab element play important role irf induction irf expression depends binding transactivator c rel element irf promoter',
#  'furthermore methylation central cpg nfkappab element inhibits binding nfkappab protein complex promoting significance observed methylation difference irf positive negative cell',
#  'via vitro methylation reporter gene assay could clearly appoint silencing irf promoter methylation effect may thus mechanism irf deregulation vivo',
#  'one possible cause aberrant methylation tumorigenesis increased level dnmts pathogenetic process',
#  'colon lung hematologic malignancy overexpression dnmt maintenance dnmt detected',
#  'furthermore shown cml cell acute phase exhibited elevated level three known dnmts cml cell chronic phase expressed normal level dnmts compared normal bone marrow cell',
#  'interestingly positive correlation dnmt expression level hypermethylation p ink b detected aml',
#  'work detect significant mrna expression difference selected dnmt mbp making unlikely cause observed methylation thus irf expression difference leukemia cell',
#  'finding irf expression silenced promoter hypermethylation might represent mechanism account previously observed loss irf expression cml',
#  'indeed several clinical trial leukemia patient patient myelodysplastic syndrome demonstrated potential clinical benefit treatment demethylating agent',
#  'expression another irf ifn consensus sequence binding protein icsbp irf impaired myeloid leukemia especially cml',
#  'contrast irf loss irf could reverted icsbp negative cell line em cml k lama treatment azadc figure azadc effect icsbp level icsbp positive u cell figure',
#  'data suggest distinct regulatory mechanism two irfs',
#  'irf similar many classical tumor suppressor gene p ink b p ink p may thus subject alteration promoter methylation status leading expression change might contribute initiation progression cancer',
#  'still obvious functional diversity irf remains remarkable fully explained irf promoter methylation status',
#  'example irf primarily known oncogenic feature',
#  'multiple myeloma mm translocation chromosome q reported lead fusion gene immunoglobulin heavy chain igh irf resulting subsequent overexpression irf',
#  'addition abundant irf expression found marker various subset lymphoma diffuse large b cell lymphoma primary effusion lymphoma marginal zone lymphoma adult cell leukemia',
#  'draw complex picture role irf',
#  'regulation irf may promote leukemogenesis myeloid cell context recently confirmed irf icsbp double knock mouse irf regulation may induce growth advantage lymphoma mm',
#  'taken together data suggest irf promoter methylation regulates irf expression aberrant expression irf certain type leukemia may consequence irf promoter hypermethylation',
#  'foxp represses retroviral transcription targeting nf kappab creb pathway',
#  'forkhead box fox winged helix transcription factor regulate multiple aspect immune responsiveness foxp recognized essential functional marker regulatory cell',
#  'herein describe downstream signaling pathway targeted foxp may negatively impact retroviral pathogenesis',
#  'overexpression foxp hek purified cd cell resulted dose dependent time dependent decrease basal level nuclear factor kappab nf kappab activation',
#  'deletion carboxyl terminal forkhead fkh domain critical nuclear localization dna binding activity abrogated ability foxp suppress nf kappab activity hek cell jurkat primary human cd cell',
#  'demonstrate foxp suppressed transcription two human retroviral promoter hiv human cell lymphotropic virus type htlv utilizing nf kappab dependent nf kappab independent mechanism',
#  'examination latter identified camp responsive element binding protein creb pathway target foxp',
#  'finally comparison percent foxp cd cd cell htlv proviral load htlv infected asymptomatic carrier patient htlv associated myelopathy tropical spastic paraparesis suggested high foxp expression associated low proviral load absence disease',
#  'result suggest expanded role foxp regulating nf kappab creb dependent cellular viral gene expression',
#  'past several year mounting evidence shown immune tolerance healthy individual maintained population lymphocyte known regulatory cell tregs',
#  'component system protein known foxp shown absolutely required development function tregs',
#  'foxp play important role maintaining immune tolerance blocking cell proliferation production inflammatory protein known cytokine little known molecular mechanism used foxp accomplish event',
#  'present study expands understanding foxp maintains check inappropriate immune response demonstrating foxp block activation key inducible protein nuclear factor kappab nf kappab camp responsive element binding protein creb',
#  'since nf kappab creb integrally involved controlling cell cycle progression inflammatory cytokine production replication numerous virus level transcription understanding mechanism foxp function regulate cellular viral gene expression may aid discovery therapeutic approach designed rescue expression function foxp found deficient several autoimmune disease virus induced disorder',
#  'immunological tolerance self antigen result deletion self reactive lymphocyte thymus central tolerance suppression activation potentially self reactive lymphocyte periphery peripheral tolerance',
#  'suppression pathogenic cell response mediated naturally arising cd cd regulatory cell tregs',
#  'deficiency treg development function linked severe autoimmune disorder known immune dysregulation polyendocrinopathy enteropathy x linked syndrome ipex',
#  'addition recent study provided strong evidence dysregulation treg development function may significant factor pathogenesis several autoimmune disorder e g multiple sclerosis myasthenia gravis type diabetes virus induced immunologic disorder e g human lymphotropic virus type htlv associated myelopathy tropical spastic paraparesis ham tsp hiv induced aid',
#  'transcription factor foxp amino acid kda protein expressed high level cd cd hi cell previously shown absolutely critical treg development function',
#  'foxp contains proline rich amino terminal domain reported function nuclear factor activated cell nf nuclear factor kappab nf kappab binding domain central region containing zinc finger leucine zipper potentially important protein protein interaction carboxyl terminal forkhead fkh domain required nuclear localization dna binding activity',
#  'functional inactivation foxp genetic mutation affecting foxp coding region demonstrated ipex repression foxp expression htlv encoded transactivator protein tax recently reported patient ham tsp result loss regulatory activity cd cd hi cell',
#  'although clear foxp regulates cell proliferation cytokine production little known concerning molecular mechanism foxp function',
#  'first evidence indicate foxp promotes development function regulatory cell came report ziegler colleague suggested foxp could inhibit transcriptional activation physically interacting forkhead binding site located immediately adjacent critical ci acting nf binding site found various cytokine promoter e g il promoter',
#  'study also demonstrated foxp could repress activation synthetic reporter vector containing sv promoter three tandem copy forkhead binding site',
#  'result provided additional evidence suggesting foxp transcriptional repression mediated binding sequence specific manner promoter containing forkhead binding site',
#  'recent study bettelli colleague demonstrated foxp could inhibit nf well nf kappab activation although mechanism suppression shown involve direct protein protein interaction nf nf kappab foxp rather binding foxp promoter element adjacent ci acting nf nf kappab site',
#  'collectively data suggested foxp may function transcriptional repressor potentially formation dna protein protein protein interaction',
#  'present study expanded upon observation defining additional requirement foxp mediated repression nf kappab activation investigated whether foxp could target additional signaling pathway examining transcriptional activation nf kappab dependent nf kappab independent retroviral pathogen',
#  'characterization molecular target foxp mechanism utilized foxp support treg development function aid understanding role tregs play pathogenesis human autoimmune disease',
#  'foxp suppresses nf kappab dependent transcriptional activation',
#  'ascertain molecular mechanism foxp function promote regulatory function cd cd hi cell first confirmed function foxp repressor activation nf kappab previously implicated target forkhead winged helix family transcription factor e g foxj foxo',
#  'analyzed effect foxp overexpression nf kappab activation hek cell dose response time course analysis',
#  'transfection hek cell nf kappab luciferase reporter vector presence absence increasing concentration foxp expression vector control vector enhanced green fluorescent protein egfp performed cell harvested h assay luciferase activity foxp mrna expression',
#  'result indicated concentration foxp transfected cell increase ng level nf kappab activation decrease proportionally figure',
#  'foxp mrna also assayed monitor activity foxp expression vector figure b',
#  'since nf kappab activation partially affected transfection high concentration control vector determined fold inhibition nf kappab activation foxp compared control vector concentration figure',
#  'fold inhibition nf kappab activation directly proportional level foxp mrna expression detected real time rt pcr',
#  'determine level foxp mediated suppression nf kappab activation time hek cell transfected nf kappab luciferase reporter vector expression vector encoding foxp egfp control vector harvested',
#  'shown figure c nf kappab activation suppressed overexpression foxp time point',
#  'extending result established vitro hek cell line primary human lymphocyte overexpression foxp purified cd cell three healthy donor also regulated steady state level nf kappab activation figure',
#  'result recapitulate bettelli colleague demonstrating foxp function part block nf kappab dependent transcription human cell line well primary human cd cell',
#  'carboxyl terminal fkh domain required suppression nf kappab activation cell',
#  'define requirement foxp respect inhibition nf kappab dependent transcription utilized mutant foxp lacking fkh domain figure similar scurfy mutant foxp mouse mutant foxp protein patient ipex',
#  'unlike full length foxp localizes almost exclusively nucleus bind sequence specific manner forkhead binding site deltafkh mutant fails localize nucleus thus interact promoter element nuclear protein',
#  'therefore utilized deltafkh mutant determine whether nuclear localization function associated fkh domain foxp prerequisite inhibition nf kappab activation',
#  'although foxp interaction nf kappab presumably take place nucleus may also possible cytoplasmic foxp protein bind nf kappab cytoplasm prevent localization nucleus following activation stimulus',
#  'overexpression full length foxp deltafkh able suppress activation cotransfected nf kappab reporter vector hek cell figure b',
#  'foxp deltafkh expressed high level following transfection detected real time rt pcr unpublished data',
#  'data appear suggest carboxyl terminal fkh domain critically important foxp regulate nf kappab dependent transcription',
#  'however nf kappab activation blocked similar extent full length foxp deltafkh jurkat cell figure c primary human cd cell figure',
#  'western blot analysis nf kappab p expression demonstrated foxp deltafkh block nf kappab activation level p protein expression figure e',
#  'result interesting respect foxp function suggest carboxyl terminal fkh domain possibly nuclear localization dispensable foxp function cell population',
#  'alternative interpretation may include possibility localization deltafkh differ epithelial cell cell',
#  'either case result suggest cell type specific mechanism action foxp mutant',
#  'foxp suppresses hiv gene expression part blocking activation nf kappab',
#  'foxp function repressor nf kappab dependent gene expression hypothesized foxp overexpression could selectively regulate transcription promoter previously shown responsive nf kappab',
#  'address question examined transcriptional activation hiv ltr contains two tandem ci acting nf kappab binding site located position respect transcription initiation site',
#  'nf kappab play crucial role regulating gene expression directed hiv ltr cd cell',
#  'overexpression full length foxp deltafkh hek cell able inhibit basal activation hiv ltr figure similar previously demonstrated synthetic nf kappab reporter vector figure b',
#  'furthermore hiv ltr activation suppressed full length foxp deltafkh jurkat cell figure b',
#  'demonstrate foxp mediated hiv ltr repression associated interaction nf kappab bound hiv ltr compared basal activation hiv ltr identical hiv ltr lacking nf kappab site located hiv delta kappab ltr figure c',
#  'mutant hiv ltr construct exhibited reduced level transcription compared parental hiv ltr purified healthy donor cd cell unpublished data',
#  'however directly comparing effect foxp overexpression activation two viral promoter demonstrated foxp capable suppressing transcriptional activation hiv ltr figure compared mutated hiv ltr figure e',
#  'result suggest foxp regulation hiv ltr activation mediated least part ci acting nf kappab binding site',
#  'residual level inhibition hiv delta kappab ltr foxp may due nf binding site located upstream nf kappab site within hiv ltr',
#  'transactivation function htlv tax suppressed foxp',
#  'previous study bettelli colleague demonstrated foxp repress basal level nf kappab activation well tumor necrosis factor alpha stimulated nf kappab activation',
#  'next step determine whether foxp could also suppress activation nf kappab caused strong viral transactivator protein',
#  'htlv encodes multifunctional transactivator protein tax capable activating nf kappab creb pathway',
#  'since htlv tax protein function multiple level cytoplasm nucleus stimulate activation nf kappab hypothesized overexpression foxp may interfere process',
#  'however since tax dependent htlv gene expression independent nf kappab also hypothesized foxp would affect tax dependent activation htlv ltr',
#  'test hypothesis overexpressed htlv tax full length foxp deltafkh hek cell cotransfected htlv ltr nf kappab reporter vector',
#  'shown figure htlv tax strongly regulated nf kappab dependent transcriptional activation fold',
#  'interestingly overexpression foxp deltafkh suppressed tax mediated activation nf kappab dependent transcription',
#  'observation suggest carboxyl terminal fkh domain required inhibiting activation nf kappab presence tax hek cell strikingly similar requirement foxp inhibition basal nf kappab activation shown figure b',
#  'transactivation htlv ltr stimulated fold overexpression tax figure b transfection foxp suppressed tax dependent htlv ltr activation although htlv ltr activation presence absence tax independent nf kappab nf another transcriptional activator known interact foxp',
#  'furthermore overexpression deltafkh also led suppression htlv transactivation tax similar extent full length foxp figure b',
#  'suppressive effect shown figure b result foxp regulating expression transfected tax plasmid determined real time rt pcr figure c',
#  'result strongly suggest foxp interacts transcriptional regulator addition nf kappab nf carboxyl terminal fkh domain therefore localization nucleus required inhibition tax mediated htlv ltr activation even hek cell',
#  'determine whether foxp inhibited transactivation function tax directly associating viral protein generated expression vector htlv tax fused frame carboxyl terminus gal dna binding domain gal bd',
#  'gal bd tax fusion protein activated transcription synthetic promoter containing five gal binding site gal bd insufficient stimulate transcription figure',
#  'transactivation gal resposive promoter gal bd tax remained relatively unaffected overexpression either egfp control foxp deltafkh suggesting foxp repress tax transactivation directly interfacing htlv tax protein',
#  'confirm foxp direct effect htlv replication transfected hek cell well characterized htlv infectious molecular clone termed ach presence full length foxp deltafkh control vector',
#  'ach previously shown direct expression viral antigen produce infectious virus transform cd cell vitro vivo',
#  'h amount viral antigen expression case tax mrna detected sensitive real time rt pcr assay',
#  'illustrated figure level tax mrna synthesized ach regulated presence foxp compared level produced presence control vector',
#  'deltafkh discernable affect tax expression',
#  'data indicate foxp capable repressing expression tax infectious htlv molecular clone',
#  'increased foxp protein expression associated low htlv proviral load',
#  'since foxp expressed almost exclusively within cd cd cell major viral reservoir htlv important determine whether association foxp htlv replication infected patient',
#  'therefore quantitated foxp protein expression cd cd cell flow cytometry htlv proviral load surrogate marker viral replication real time pcr eight patient ham tsp eight asymptomatic carrier ac',
#  'data analysis summarized table',
#  'expected patient ham tsp exhibited significantly higher proviral load indicated htlv proviral dna copy cell compared ac p',
#  'percentage foxp cell within cd cd cell population significantly greater ac ham tsp patient p',
#  'data suggest high level foxp protein expression associated reduced htlv replication vivo',
#  'also support recent report high proviral load shown correlate high tax mrna htlv infected patient associated reduced foxp expression',
#  'creb target transcriptional repression foxp',
#  'although foxp could regulate tax dependent transactivation htlv ltr figure b inhibit tax expression infectious molecular clone figure foxp failed modulate tax function absence viral promoter figure',
#  'result led u hypothesize foxp act htlv gene expression interacting protein important driving htlv ltr activity vivo',
#  'previous study demonstrated tax responsive element within htlv ltr play crucial role driving tax mediated transactivation htlv ltr',
#  'tax responsive element shown resemble creb binding site bind creb vitro vivo facilitate htlv ltr activation presence absence tax',
#  'ching colleague demonstrated addition dominant negative creb expression vector resulted nearly complete inhibition tax mediated activation htlv ltr blocking nf kappab activation addition dominant negative ikkbeta expression vector effect tax transactivation htlv ltr',
#  'therefore hypothesized foxp may inhibit tax transactivation htlv ltr via disruption creb signaling pathway',
#  'test possibility hek cell transfected htlv ltr synthetic creb reporter vector along control expression vector egfp expression vector encoding foxp deltafkh',
#  'shown figure foxp regulated basal activation htlv ltr transcription synthetic creb reporter vector suggesting foxp regulates htlv ltr activation targeting creb pathway',
#  'deletion fkh domain foxp dampened suppressive effect foxp completely abrogate suppression seen nf kappab responsive promoter hek cell',
#  'like nf kappab activation creb transcriptional activation also suppressed expression foxp similar extent deltafkh healthy donor cd cell figure b',
#  'similarly foxp deltafkh also repressed basal htlv ltr activation primary human cd cell figure c',
#  'knowledge first evidence implicating creb molecular target foxp',
#  'observed nf kappab activation deltafkh potent inhibitor creb activation cd cell hek cell indicating cell type specific mechanism action may govern function foxp mutant',
#  'determine whether foxp functioned directly signaling creb utilized expression vector encoding creb c jun member activator protein family transcription factor fused frame gal bd gal bd creb gal bd c jun',
#  'shown figure activation gal responsive reporter vector gal bd creb regulated foxp compared control vector egfp indicating foxp function directly indirectly interacting creb',
#  'however foxp failed markedly affect transcriptional activation gal bd c jun c jun also demonstrated bind htlv ltr gal bd tax see figure',
#  'importantly mechanism foxp mediated inhibition creb dependent transcription due block creb protein expression determined western blot analysis figure e',
#  'although result demonstrate foxp function co repressor creb activation addition nf kappab nf unable detect direct physical interaction creb foxp coimmunoprecipitation mammalian two hybrid analysis unpublished data',
#  'therefore data suggest foxp may interfere creb signaling upstream event phosphorylation creb recruitment function coactivator protein creb binding protein cbp p',
#  'foxp antagonizes creb transcriptional activation disrupting coactivator recruitment',
#  'stimulation creb dependent transcription reagent activate adenylate cyclase increase camp level e g forskolin increase transactivation potential creb phosphorylation serine protein kinase permit binding recruitment coactivators cbp p promoter',
#  'phosphorylation serine however affect dna binding activity creb case',
#  'addition forskolin hek cell stimulated activation creb reporter vector fold figure',
#  'overexpression foxp capable regulating forskolin induced creb transcriptional activation',
#  'functional interaction foxp creb affect dna binding activity creb show modest decrease activating transcription factor atf dna binding activity presence forskolin determined transcription factor elisa figure b',
#  'foxp shown bind repress activation nf kappab nf exactly foxp function bring affect elucidated',
#  'determine foxp block creb dependent transcription examined whether foxp capable disrupting recruitment coactivator protein preventing phosphorylation creb serine prerequisite coactivator recruitment',
#  'since event required creb dependent gene expression hypothesized foxp may affect creb activation step',
#  'determine whether foxp disrupt function recruitment coactivator protein p introduced gal reporter vector gal bd creb expression vector hek cell absence presence foxp p control expression vector figure c',
#  'expected p overexpression stimulated transcription gal bd creb fusion protein',
#  'foxp repressed basal level gal bd creb activation fold effectively neutralizing gal bd creb activation presence p',
#  'next analyzed effect foxp phosphorylation creb serine forskolin treated hek cell western blot analysis',
#  'overexpression foxp failed reduce detectable level creb phosphorylation using phosphospecific antibody creb unpublished data',
#  'however attempted determine whether foxp could physically interact coactivator protein p found p immunoprecipitated foxp protein overexpressed hek cell figure',
#  'collectively result suggest foxp antagonizes creb dependent gene expression directly interacting coactivator p interfering function recruitment creb responsive promoter sequence',
#  'present study show foxp function potent repressor nf kappab creb dependent transcriptional activation',
#  'furthermore carboxyl terminal fkh domain appears dispensable mediating effect least cell population',
#  'observation may become important light recent report suggesting foxp expression thymic epithelial cell crucial directing development cell thymus',
#  'interestingly majority genetic mutation associated ipex severe autoimmune disorder caused functional inactivation foxp map carboxyl terminal fkh domain leucine zipper domain central region protein',
#  'one mutation associated ipex date mapped amino terminal proline rich region',
#  'possible fkh domain complex tertiary structure particularly sensitive misfolding caused genetic mutation intact fkh domain absolutely critical promoting foxp function nucleus whereas structure amino terminal proline rich region may tolerate certain mutation long nf kappab nf binding motif remains unaltered',
#  'motif may also include zinc finger domain',
#  'logical region may targeted amino terminal proline rich region foxp rel homology domain found nf kappab nf family protein',
#  'region may also important respect foxp function leucine zipper domain demonstrated number mutation associated ipex mapped region foxp',
#  'role domain foxp function remains uncharacterized may play role dimer formation foxp family member',
#  'pathogenesis number retroviral induced immunologic disorder hiv aid htlv ham tsp associated dysregulation foxp expression also examined role foxp retroviral gene expression',
#  'hiv ltr activation cd cell critically dependent two tandem nf kappab site located nucleotide position within hiv enhancer region whereas htlv ltr activation presence absence htlv encoded transactivator protein tax independent nf kappab',
#  'knowledge first time foxp shown direct effect hiv ltr transcription',
#  'deletion nf kappab site within hiv enhancer region reduced responsiveness hiv ltr foxp mediated suppression',
#  'addition fkh domain foxp required inhibitory effect hek cell jurkat cell similar foxp mediated suppression synthetic nf kappab reporter',
#  'direct effect foxp regulating hiv gene expression correlate well recently reported evidence indicating higher regulatory activity cd cd cell hiv infected patient associated lower hiv viral load patient',
#  'foxp also affected two well known function htlv tax transactivation nf kappab pathway surprisingly transactivation htlv ltr',
#  'transactivation htlv ltr tax involves interaction atf creb factor tax nucleus',
#  'binding tax enhances atf creb dimerization promotes assembly tax atf creb complex onto specific sequence viral promoter known tax responsive element',
#  'series step allows tax recruit coactivator protein cbp p viral promoter facilitate high level viral gene expression',
#  'transactivation nf kappab pathway tax inhibited overexpression full length foxp deltafkh seen basal activation hiv ltr synthetic nf kappab reporter hek cell',
#  'however tax mediated transactivation htlv ltr inhibited overexpression full length foxp well deltafkh hek cell cd cell',
#  'demonstrated foxp directly affect functioning tax rather foxp targeted transcription factor required tax transactivation e nf kappab unknown cellular factor identified study creb',
#  'negative effect foxp htlv gene expression confirmed utilizing htlv infectious molecular clone',
#  'importantly demonstrated htlv infected individual highest level foxp protein expression within cd cd cell population exhibited lower proviral load individual lowest level foxp protein expression',
#  'previous study demonstrated htlv proviral load directly correlate htlv tax mrna load frequency immunopathogenic virus specific cd cell disease severity patient ham tsp',
#  'result important implication utility foxp controlling viral gene expression thus pathogenesis ham tsp',
#  'therefore foxp becomes attractive target development novel therapeutic application directed modulating expression important regulatory protein especially light recent observation expression foxp also regulated htlv tax',
#  'activation htlv ltr depends primarily atf creb protein whether presence absence tax investigated whether foxp could interact additional cellular signaling pathway',
#  'dna binding activity creb case constitutive transactivation potential creb regulated phosphorylation creb recruitment cbp p',
#  'data demonstrate foxp interferes latter two process recruitment coactivator protein p resulting transcriptional activation blocked foxp',
#  'may result physical interaction detected foxp p',
#  'respect htlv ltr activity full length foxp inhibited basal tax dependent transcription deltafkh appeared le effective suppressing basal activation inhibition compared tax dependent activation inhibition',
#  'effect deltafkh basal activation htlv ltr hek cell similar shown synthetic creb reporter suggesting fkh domain foxp important level',
#  'observed nf kappab activation foxp mutant lacking fkh domain stronger inhibitor creb activation cd cell hek epithelial cell',
#  'therefore appears cd cell fkh domain dispensable proper functioning foxp respect nf kappab creb activation',
#  'summary knowledge first direct evidence implicating role treg specific transcription factor foxp regulating retroviral gene expression',
#  'addition identify creb pathway molecular target foxp',
#  'since creb shown regulate multiple gene involved transcription e g jund c fo signal transducer activated cell stat cell cycle e g p ink b cyclin cyclin immune regulation e g il il cell receptor alpha reviewed finding presented report broaden potential range signaling pathway control regulatory protein foxp',
#  'evidence stress importance foxp expression treg function development maintenance protective immunity hiv htlv',
#  'based recent finding foxp may limit hiv htlv transcription interfering activation nf kappab creb pathway',
#  'however observing inhibitory effect absolute low level viral gene expression may persist cd cell particular regulatory cell known reservoir hiv htlv result accumulation viral protein either stimulate nf kappab creb activation directly inhibit foxp expression function',
#  'imbalance nf kappab creb activation caused viral gene product may crucial step pathogenesis virus induced immunological disorder aid ham tsp',
#  'future study directed identifying characterizing cellular protein interact foxp nucleus cytoplasm order better address foxp function guide development function regulatory cell health disease',
#  'cell culture',
#  'hek cell cultured dulbecco modified eagle medium invitrogen carlsbad california united state',
# ...
#  'runx highly expressed peripheral cd cell bet runx cooperation observed earlier cd cell examined role runx effector ctl differentiation',
#  'isolated cd cell runx ko mouse outbred icr background wt runx littermates positive selection anti cd magnetic bead fig available http www jem org cgi content full jem dc',
#  'strikingly runx cd cell strongly impaired ability differentiate effector ctls judged expression perforin granzyme b ifn gamma fig',
#  'compared wt cell perforin mrna protein expression essentially undetectable runx cell day culture fig b',
#  'runx cell also detectable eomes expression contrast bet expression unimpaired fig',
#  'furthermore runx required maximal production ifn gamma tnf il cd cell restimulated day fig c',
#  'previously reported th cell differentiation regulated feed forward loop bet regulated early induces runx bet runx cooperate induce ifn gamma silence il thus promoting stable differentiation toward th lineage',
#  'runx appeared necessary eomes induction fig b kinetics eomes expression paralleled perforin expression fig c overexpression eo vp either wt bet deficient cell led increase perforin ifn gamma expression fig b asked whether ctl differentiation also potentially regulated feed forward loop involving two class runx box transcription factor',
#  'specifically asked whether runx necessary eomes induction cooperated eomes regulate transcription effector ctl marker perforin ifn gamma granzyme b',
#  'test hypothesis used chromatin immunoprecipitation chip assay ask whether eomes runx bound regulatory region prf ifng gzmb gene fig',
#  'protein associated gene regulatory region differentiated ctls',
#  'runx bound prf gzmb transcription start site tss known il responsive enhancer located near kb prf gene distal ctl specific dnase hypersensitive site prf locus ifng promoter near tss previously reported th cell several dnase hypersensitive site ifng locus fig depicted',
#  'eomes bound primarily prf tss kb enhancer binding substantially greater observed promoter il rb gene known direct target eomes comparable observed ifng tss known target box protein th cd cell fig',
#  'determine whether runx controlled expression ctl effector gene induction eomes retrovirally expressed runx eo vp cd cell runx mouse',
#  'limited number cd cell mouse saw difference runx cd cd sp cd cd dp cell previous experiment used total runx cd cell without fractionation recipient retroviral transduction',
#  'reconstitution runx cd cell runx restored expression eomes well perforin granzyme b ifn gamma fig b',
#  'addition runx cell showed compensatory regulation runx suppressed upon reconstitution runx indicating runx target repression runx',
#  'notably eo vp regulate perforin expression expressed runx cell even though restored capacity induce ifn gamma expression upon tcr restimulation fig b',
#  'result suggests strongly perforin expression requires runx eomes',
#  'expected defect perforin granzyme b expression runx cd cell showed defective cytolytic activity mixed lymphocyte reaction',
#  'however tcr stimulated runx cd cell effective wt cell killing tumor cell redirected ctl assay',
#  'furthermore cd cell peritoneal cavity runx mouse immunized certain tumor cell effectively killed target',
#  'therefore although activation perforin granzyme b machinery defective runx cd cell cell entirely devoid cytolytic activity could still effectively kill target possibly alternative mechanism fa fa ligand pathway',
#  'runx box factor control complex program transcriptional regulation ctl differentiation',
#  'collectively data provide evidence runx together box factor orchestrates complex program transcriptional regulation differentiating ctl fig c',
#  'runx present naive cd cell activation',
#  'represses runx positive role induction eomes granzyme b perforin ifn gamma',
#  'runx bind promoter putative regulatory region latter three gene suggesting direct effect gene expression',
#  'additional experiment needed determine whether eomes runx also direct target gene runx',
#  'surprisingly runx contributed optimal expression tnf il ifn gamma day fig',
#  'tnf il requirement runx subsides day fig c possibly compensation runx derepressed runx cell fig',
#  'runx continues required ifn gamma expression even day perhaps role induction eomes expression fig',
#  'unexpected finding two box transcription factor bet eomes regulated different kinetics cd cell culture condition nonredundant role subsequent expression key effector protein fig c',
#  'bet needed early confer activated cd cell competence produce ifn gamma upon restimulation function le important later time',
#  'eomes induced late function downstream runx may substitute bet promoting acute expression ifn gamma restimulated ctls',
#  'indeed bet eomes contribute perforin expression nk cell eomes induces granzyme b effectively bet developing th cell thus relative role box transcription factor vary depending cell type',
#  'surprisingly however eomes bet appeared nonredundant ability induce two marker ctl function prf gzmb fig c',
#  'rather bet eomes involved regulating granzyme b perforin expression respectively regulation bet eomes mrna protein closely preceded regulation gzmb prf mrna protein respectively',
#  'bet role perforin expression culture condition eo vp affect granzyme b expression expressed bet runx cell',
#  'conventional eomes deficient mouse die precursor cell isolated bone marrow transfer cell conditionally deficient eomes recently described unable introduce runx eomes deficient cd cell test formally whether eomes cooperated runx induce perforin expression',
#  'collectively data consistent transcriptional network preexisting runx cooperates induced box factor bet eomes il rbeta signal unpublished data orchestrate ctl differentiation fig c',
#  'data recall feed forward interaction bet runx previously described cd th cell distinct two respect differentiating th cell bet induced tcr signal ifn gamma turn induces runx whereas differentiating cd cell preexisting runx required induce box transcription factor eomes',
#  'whole genome experiment system required establish whether cooperation box runx family transcription factor general feature cellular differentiation program',
#  'antibody reagent',
#  'following antibody used intracellular surface stain obtained ebioscience anti il anti ifn gamma anti tnf anti granzyme b anti cd anti cd anti cd',
#  'anti cd purchased bd',
#  'chip experiment anti eomes antibody obtained abcam anti runx antibody produced groner laboratory',
#  'following antibody used immunoblotting anti perforin abcam anti eomes abcam anti pol ii santa cruz biotechnology inc',
#  'bet antibody provided l',
#  'glimcher harvard school public health boston',
#  'following reagent used experiment presented report annexin v fitc apoptosis detection kit bd cd negative isolation kit invitrogen cd microbeads miltenyi biotec sybr green pcr core reagent applied biosystems',
#  'gp peptide kavynfatc synthesized tuft university core facility mm stock solution prepared dmso',
#  'isolation culture primary cd cell',
#  'cd cell wk old tcra x p tcr transgenic taconic c bl j wt tbx jackson laboratory mouse purified purity negative selection invitrogen pooled spleen lymph node cell',
#  'cd cell runx mouse icr background purified positive selection miltenyi biotec',
#  'mouse maintained specific pathogen free barrier facility used according protocol approved immune disease institute harvard medical school animal care use committee',
#  'stimulation purified cd cell cultured cell ml ml flask coated mug ml anti cd clone c anti cd clone pretreatment mug ml goat anti hamster igg',
#  'h cell removed tcr stimulation recultured concentration x cell ml medium supplemented u ml rhil',
#  'every h viable cell counted readjusted x cell ml fresh medium containing corresponding amount rhil',
#  'isolation cd cell runx mouse',
#  'runx deficient cell fail silence cd expression normally fig',
#  'therefore fractionated positively selected cd cell runx ko mouse cd cd sp cd cd dp cell separation using anti cd magnetic bead',
#  'yielded runx ko sp enriched population contained cd cd cell ko dp enriched population contained cd cd cell fig',
#  'cell stimulated anti cd anti cd removing tcr stimulus culturing medium containing u ml il',
#  'previously reported tcr induced proliferation runx cd cell severely impaired irrespective cd expression fig',
#  'however runx cell showed cell surface expression pattern indicative activated cell including regulation cd cd fig',
#  'expected ability regulate cd runx cd cell responded il supplementation day efficiently expanded day culture period albeit slower rate compared wt cell fig',
#  'although fraction ko dp cell silenced cd expression activation ratio sp dp cell enriched population remained constant thereafter observe major difference two population throughout culture period indicating term effector ctl differentiation culture condition runx cd cell also coexpress cd indistinguishable',
#  'data presented fig',
#  'runx ko sp cell whereas shown fig',
#  'total runx ko cd cell',
#  'facs based cytotoxicity assay',
#  'measure cytotoxicity el thymoma target cell loaded mum gp peptide h h coincubation p cd cell effector target ratio indicated figure well round bottom plate',
#  'coincubation period cell stained annexin v fitc anti cd allophycocyanin',
#  'data analysis performed flowjo software tree star inc el target cell cd negative event gated percentage annexin v target cell determined',
#  'cytokine surface marker staining',
#  'ass cytokine production cell restimulated nm pma mum ionomycin h unless indicated otherwise figure intracellular cytokine stain performed previously described',
#  'detect expression surface molecule cell washed pb resuspended facs wash buffer fbs sodium azide mm hepes x pb containing antibody indicated figure previously optimized concentration incubated min room temperature rt washed resuspended formaldehyde fixative solution acquisition facscalibur bd',
#  'retroviral transduction primary cd cell',
#  'transduction experiment viral supernatant generated calcium phosphate transfection phoenix cell concentration overnight centrifugation g',
#  'approximately h initial tcr activation cd cell per well well plate culture medium removed replaced complete medium supplemented mug ml polybrene containing fresh plus concentrated virus',
#  'plate centrifuged g h rt returning degreesc additional h',
#  'retroviral construct eomes vp mig control empty vector gift l',
#  'reiner university pennsylvania philadelphia pa',
#  'chip real time pcr analysis',
#  'x cd cell per immunoprecipitation fixed adding th volume fixation solution formaldehyde mm nacl mm edta mm egta mm hepes volume culture medium incubated min rt',
#  'fixation stopped mm glycine ice min',
#  'fixed cell washed x cold pb x cold solution mm tris ph mm edta mm egta triton x x cold solution ii mm tris ph mm edta mm egta mm nacl',
#  'wash cell pellet resuspended x cell ml chip lysis buffer mm nacl mm tris ph triton x sd deoxycholate plus protease phosphatase inhibitor chromatin sheared sonicator yield kb dna fragment',
#  'preclearing sheared chromatin protein sepharose bead removing input chromatin immunoprecipitation performed adding optimized antibody amount per x cell equivalent mug anti eomes dilution anti runx followed overnight incubation degreesc protein sepharose bead added last h incubation period',
#  'bead washed x ripa buffer mm tris ph mm nacl mm edta np sd deoxycholate x high salt buffer mm tris ph mm nacl mm edta np sd x te buffer',
#  'last wash dna eluted resuspending bead elution buffer sd mm nahco',
#  'input chip chromatin treated rnase mug total h degreesc followed addition proteinase k mug total overnight incubation degreesc reverse cross linking',
#  'dna purified qiaquick column gel extraction kit qiagen according manufacturer instruction resuspended mul volume',
#  'real time pcr detection immunoprecipitated target using sybr green pcr kit standard curve obtained serial dilution input dna sample mul chip dna used per pcr reaction performed duplicate',
#  'melt curve agarose gel analyzed ensure amplification specific target sequence',
#  'refer table available http www jem org cgi content full jem dc list primer set',
#  'data presented number immunoprecipitated target sequence relative input chromatin assuming two copy target sequence per cell equivalent used chip',
#  'northern western blot analysis',
#  'rna isolation northern blot analysis performed previously described',
#  'brief mug total rna loaded per lane transferred positively charged nylon membrane hybond n ge healthcare confirmed ethidium bromide staining ribosomal rna specie membrane',
#  'membrane hybridized ng ml alpha p dctp labeled trichloroacetic acid precipitable probe expresshyb hybridization buffer clontech laboratory inc',
#  'cdna probe confirmed appropriate single copy specificity condition using genomic southern blot analysis',
#  'band intensity acquired phosphorimaging analysis',
#  'western analysis whole cell protein lysates obtained cd cell time point indicated figure clonal expansion u ml il lysis buffer mm tris ph mm nacl glycerol mm edta np resuspending sample mul per cell incubating ice min presence protease inhibitor',
#  'immunoblot analysis performed antibody indicated figure sd page mug total protein loaded per well',
#  'quantification detected protein performed intelligent dark box unit la fujifilm normalized loading amount rna pol ii detected lane',
#  'online supplemental material',
#  'fig show characterization peripheral cd cell runx mouse',
#  'fig',
#  'show effector protein expression runx wt ko cell day vitro culture',
#  'primer sequence used chip experiment shown table',
#  'online supplemental material available http www jem org cgi content full jem dc',
#  'supplementary material',
#  'supplemental material index',
#  'kinetics gene expression cd cell differentiation',
#  'kinetics prf gzmb tbx bet eomes mrna expression differentiating p cd cell analyzed northern blotting',
#  'rna day th cell used control',
#  'size mrna transcript indicated',
#  'b quantification relative mrna amount phosphorimager analysis',
#  'c kinetics protein expression differentiating p cd cell analyzed immunoblotting',
#  'size protein band indicated',
#  'relative protein amount quantified western blot',
#  'e intracellular staining granzyme b ifn gamma tnf',
#  'granzyme b staining specific relative isotype control depicted',
#  'cell restimulated pma ionomycin h',
#  'f facs based assay measure cytolytic activity p cd cell el target loaded mum gp peptide effector target ratio',
#  'percentage annexin v apoptotic target cell cd negative el target population dot plot determined histogram',
#  'cytolytic activity blocked incubation mm egta depicted confirming involvement granule exocytosis perforin granzyme b pathway',
#  'data representative least five e three f independent experiment',
#  'regulation perforin granzyme b ifn gamma expression bet eomes differentiating ctls',
#  'ifn gamma expression wt tbx bet deficient tbx cell',
#  'naive cd cell cell activated cultured restimulated pma ionomycin h ifn gamma expression assessed intracellular staining',
#  'number show percentage ifn gamma cell',
#  'b northern blot analysis prf gzmb mrna expression wt bet deficient cd cell activated either left uninfected uninf transduced retrovirus expressing eomes vp eo vp empty ire gfp cassette gfp',
#  'total cellular rna analyzed day culture',
#  'frequency transduced cell culture equivalent construct approximately gfp cell depicted',
#  'c granzyme b ifn gamma expression tbx tbx cell analyzed restimulated cell cultured',
#  'ifn gamma production cell transduced eo vp control gfp retrovirus rv measured day h restimulation pma ionomycin',
#  'number show percentage gfp ifn gamma cell',
#  'result representative three c two b independent experiment',
#  'key role runx effector ctl differentiation',
#  'western analysis runx eomes bet perforin expression runx versus runx cd sp cell differentiated',
#  'beta actin used loading control',
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
Tf = TfidfVectorizer()
X = Tf.fit_transform(corpus).toarray()

# %%
## Handling categorical variable using target guided ordinal encoding
y.head()
# Out:
# 0    Negative_regulation
# 1             Regulation
# 2    Positive_regulation
# 3             Regulation
# 4             Regulation
# Name: EventType, dtype: object

# %%
y.value_counts().sort_values()
# Out:
# Protein_catabolism       20
# Phosphorylation          52
# Localization             89
# Transcription           187
# Binding                 439
# Regulation              445
# Negative_regulation     521
# Gene_expression         785
# Positive_regulation    9488
# Name: EventType, dtype: int64

# %%
y.value_counts().sort_values().index
# Out:
# Index(['Protein_catabolism', 'Phosphorylation', 'Localization',
#        'Transcription', 'Binding', 'Regulation', 'Negative_regulation',
#        'Gene_expression', 'Positive_regulation'],
#       dtype='object')

# %%
ordinal_labels = y.value_counts().sort_values().index

# %%
enumerate(ordinal_labels,1)
# Out:
# <enumerate object at 0x0000028D4F76D800>

# %%
ordinal_labels2={k:i for i,k in enumerate(ordinal_labels,1)}
ordinal_labels2
# Out:
# {'Protein_catabolism': 1,
#  'Phosphorylation': 2,
#  'Localization': 3,
#  'Transcription': 4,
#  'Binding': 5,
#  'Regulation': 6,
#  'Negative_regulation': 7,
#  'Gene_expression': 8,
#  'Positive_regulation': 9}

# %%
y = y.map(ordinal_labels2)

# %%
X.shape, y.shape
# Out:
# ((12026, 8992), (12026,))

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((8418, 8992), (3608, 8992), (8418,), (3608,))

# %%
## Naive Baye's Classifier
from sklearn.naive_bayes import MultinomialNB
naive = MultinomialNB()
naive.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score
y_pred = naive.predict(X_test)
acc = accuracy_score(y_pred,y_test)
acc
# Out:
# 0.7827050997782705

# %% [markdown]
# ## Multinomial Classifier with HyperParameter

# %%
classifier = MultinomialNB(alpha=0.1)

# %%
import numpy as np
previous_score=0
for alpha in np.arange(0,1,0.1):
    sub_classifier=MultinomialNB(alpha=alpha)
    sub_classifier.fit(X_train,y_train)
    y_pred = sub_classifier.predict(X_test)
    score = accuracy_score(y_pred,y_test)
    if score > previous_score:
        classifier = sub_classifier
    print("Alpha: {}, score : {}".format(alpha,score))
# Out:
# C:\Users\ICON\anaconda3\lib\site-packages\sklearn\naive_bayes.py:508: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   warnings.warn('alpha too small will result in numeric errors, '
# Alpha: 0.0, score : 0.7657982261640798
# Alpha: 0.1, score : 0.772450110864745
# Alpha: 0.2, score : 0.7768847006651884
# Alpha: 0.30000000000000004, score : 0.779379157427938
# Alpha: 0.4, score : 0.7796563192904656
# Alpha: 0.5, score : 0.7810421286031042
# Alpha: 0.6000000000000001, score : 0.7818736141906873
# Alpha: 0.7000000000000001, score : 0.782150776053215
# Alpha: 0.8, score : 0.7824279379157428
# Alpha: 0.9, score : 0.7824279379157428

# %% [markdown]
# ## Passive Aggressive Classifier Algorithm

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
linear_clf = PassiveAggressiveClassifier()

# %%
linear_clf.fit(X_train,y_train)
y_pred = linear_clf.predict(X_test)
acc = accuracy_score(y_pred,y_test)
acc
# Out:
# 0.707039911308204

# %% [markdown]
# ## Random forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
random = RandomForestClassifier()
random.fit(X_train,y_train)
y_pred = random.predict(X_test)
acc = accuracy_score(y_pred,y_test)
acc
# Out:
# 0.7854767184035477

# %%
## Hyperparameter tuning
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
param_grid = {
    'n_estimators':[25,50,100,150],
    'max_depth': [3,6,9],
    'max_leaf_nodes': [3,6,9]
}

# %%
grid_search = GridSearchCV(RandomForestClassifier(),param_grid=param_grid)
grid_search.fit(X_train,y_train)
y_pred = grid_search.predict(X_test)
acc = accuracy_score(y_pred,y_test)
acc
# Out:
# 0.7832594235033259
